# %% [markdown]
# # Aula 04 - Exploração e Visualização
#
# Uma parte fundamental do kit de ferramentas do cientista de dados é a visualização de dados. Embora seja muito fácil criar visualizações, é muito mais difícil produzir boas visualizações.
#
# Existem dois usos principais para visualização de dados:
#
#     Para explorar dados;
#     Para comunicar dados.
#
# Nesta aula, nos concentraremos em desenvolver as habilidades que você precisará para começar a explorar os seus próprios dados e produzir as visualizações que usaremos ao longo do curso.
#
# Como a maioria dos tópicos que veremos, a visualização de dados é um rico campo de estudo que merece o seu próprio curso.
#
# No entanto, vamos tentar dar uma ideia do que contribui para uma boa visualização e o que não contribui.
#
#
# ## Objetivos
#
# 1. Aprender Matplotlib
# 2. Aprender conceitos básicos de visualizar dados
# 3. Um pouco mais de filtro e seleção de dados
#
# ## Resultado Esperado
#
# 1. Junto com a aula passada, ferramentas simples para exploração de dados
# 1. Muito pode ser feito sem modelos (lembre do John-Snow Experiment)
# 1. Plots + Filtros!

# %%
# -*- coding: utf8

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.ion()

# %% [markdown]
# ## EDA
#
# Vamos iniciar explorando algumas chamadas sobre como fazer merge e tratar missing data. Alguns passos simples para
# a Limpeza de Dados.

# %%
people = pd.DataFrame(
    [["Joey",      "blue",       42,  "M"],
     ["Weiwei",    "blue",       50,  "F"],
     ["Joey",      "green",       8,  "M"],
     ["Karina",    "green",  np.nan,  "F"],
     ["Fernando",  "pink",        9,  "M"],
     ["Nhi",       "blue",        3,  "F"],
     ["Sam",       "pink",   np.nan,  "M"]], 
    columns = ["Name", "Color", "Age", "Gender"])
people
# Out:
#        Name  Color   Age Gender
# 0      Joey   blue  42.0      M
# 1    Weiwei   blue  50.0      F
# 2      Joey  green   8.0      M
# 3    Karina  green   NaN      F
# 4  Fernando   pink   9.0      M
# 5       Nhi   blue   3.0      F
# 6       Sam   pink   NaN      M

# %%
email = pd.DataFrame(
    [["Deb",  "deborah_nolan@berkeley.edu"],
     ["Sam",  np.nan],
     ["John", "doe@nope.com"],
     ["Joey", "jegonzal@cs.berkeley.edu"],
     ["Weiwei", "weiwzhang@berkeley.edu"],
     ["Weiwei", np.nan],
     ["Karina", "kgoot@berkeley.edu"]], 
    columns = ["User Name", "Email"])
email
# Out:
#   User Name                       Email
# 0       Deb  deborah_nolan@berkeley.edu
# 1       Sam                         NaN
# 2      John                doe@nope.com
# 3      Joey    jegonzal@cs.berkeley.edu
# 4    Weiwei      weiwzhang@berkeley.edu
# 5    Weiwei                         NaN
# 6    Karina          kgoot@berkeley.edu

# %%
people.merge(email, 
             how = "inner",
             left_on = "Name", right_on = "User Name")
# Out:
#      Name  Color   Age Gender User Name                     Email
# 0    Joey   blue  42.0      M      Joey  jegonzal@cs.berkeley.edu
# 1    Joey  green   8.0      M      Joey  jegonzal@cs.berkeley.edu
# 2  Weiwei   blue  50.0      F    Weiwei    weiwzhang@berkeley.edu
# 3  Weiwei   blue  50.0      F    Weiwei                       NaN
# 4  Karina  green   NaN      F    Karina        kgoot@berkeley.edu
# 5     Sam   pink   NaN      M       Sam                       NaN

# %% [markdown]
# Como podemos tratar?
#
# 1. Missing data nas cores?
# 2. Missing data nos e-mails?

# %%
people['Age'] = people['Age'].fillna(people['Age'].mean())
people
# Out:
#        Name  Color   Age Gender
# 0      Joey   blue  42.0      M
# 1    Weiwei   blue  50.0      F
# 2      Joey  green   8.0      M
# 3    Karina  green  22.4      F
# 4  Fernando   pink   9.0      M
# 5       Nhi   blue   3.0      F
# 6       Sam   pink  22.4      M

# %%
email.dropna()
# Out:
#   User Name                       Email
# 0       Deb  deborah_nolan@berkeley.edu
# 2      John                doe@nope.com
# 3      Joey    jegonzal@cs.berkeley.edu
# 4    Weiwei      weiwzhang@berkeley.edu
# 6    Karina          kgoot@berkeley.edu

# %% [markdown]
# Voltando para os dados de nomes.

# %%
df = pd.read_csv('baby.csv')
df
# Out:
#               Id       Name  Year Gender State  Count
# 0              1       Mary  1910      F    AK     14
# 1              2      Annie  1910      F    AK     12
# 2              3       Anna  1910      F    AK     10
# 3              4   Margaret  1910      F    AK      8
# 4              5      Helen  1910      F    AK      7
# 5              6      Elsie  1910      F    AK      6
# 6              7       Lucy  1910      F    AK      6
# 7              8    Dorothy  1910      F    AK      5
# 8              9       Mary  1911      F    AK     12
# 9             10   Margaret  1911      F    AK      7
# 10            11       Ruth  1911      F    AK      7
# 11            12      Annie  1911      F    AK      6
# 12            13  Elizabeth  1911      F    AK      6
# 13            14      Helen  1911      F    AK      6
# 14            15       Mary  1912      F    AK      9
# 15            16      Elsie  1912      F    AK      8
# 16            17      Agnes  1912      F    AK      7
# 17            18       Anna  1912      F    AK      7
# 18            19      Helen  1912      F    AK      7
# 19            20     Louise  1912      F    AK      7
# 20            21       Jean  1912      F    AK      6
# 21            22       Ruth  1912      F    AK      6
# 22            23      Alice  1912      F    AK      5
# 23            24     Esther  1912      F    AK      5
# 24            25      Ethel  1912      F    AK      5
# 25            26   Margaret  1912      F    AK      5
# 26            27      Marie  1912      F    AK      5
# 27            28       Mary  1913      F    AK     21
# 28            29  Elizabeth  1913      F    AK      9
# 29            30   Margaret  1913      F    AK      8
# ...          ...        ...   ...    ...   ...    ...
# 5647396  5647397     Brooks  2014      M    WY      5
# 5647397  5647398     Calvin  2014      M    WY      5
# 5647398  5647399    Cameron  2014      M    WY      5
# 5647399  5647400     Dalton  2014      M    WY      5
# 5647400  5647401     Dawson  2014      M    WY      5
# 5647401  5647402     Edward  2014      M    WY      5
# 5647402  5647403      Elias  2014      M    WY      5
# 5647403  5647404       Gage  2014      M    WY      5
# 5647404  5647405     Hayden  2014      M    WY      5
# 5647405  5647406     Jasper  2014      M    WY      5
# 5647406  5647407       Jose  2014      M    WY      5
# 5647407  5647408     Kaiden  2014      M    WY      5
# 5647408  5647409      Kaleb  2014      M    WY      5
# 5647409  5647410      Kasen  2014      M    WY      5
# 5647410  5647411      Kyson  2014      M    WY      5
# 5647411  5647412      Lukas  2014      M    WY      5
# 5647412  5647413      Myles  2014      M    WY      5
# 5647413  5647414  Nathaniel  2014      M    WY      5
# 5647414  5647415      Nolan  2014      M    WY      5
# 5647415  5647416     Oakley  2014      M    WY      5
# 5647416  5647417       Odin  2014      M    WY      5
# 5647417  5647418     Paxton  2014      M    WY      5
# 5647418  5647419    Raymond  2014      M    WY      5
# 5647419  5647420    Richard  2014      M    WY      5
# 5647420  5647421      Rowan  2014      M    WY      5
# 5647421  5647422       Seth  2014      M    WY      5
# 5647422  5647423    Spencer  2014      M    WY      5
# 5647423  5647424       Tyce  2014      M    WY      5
# 5647424  5647425     Victor  2014      M    WY      5
# 5647425  5647426     Waylon  2014      M    WY      5
#
# [5647426 rows x 6 columns]

# %%
cols = ['Year', 'Count']
df[cols].groupby('Year').sum()
# Out:
#         Count
# Year
# 1910   516318
# 1911   565810
# 1912   887984
# 1913  1028553
# 1914  1293322
# 1915  1690022
# 1916  1786510
# 1917  1855696
# 1918  2013381
# 1919  1954834
# 1920  2101157
# 1921  2170892
# 1922  2127307
# 1923  2141692
# 1924  2218838
# 1925  2172403
# 1926  2137286
# 1927  2160249
# 1928  2105481
# 1929  2040623
# 1930  2070844
# 1931  1958859
# 1932  1964421
# 1933  1857674
# 1934  1933466
# 1935  1946981
# 1936  1936249
# 1937  1986759
# 1938  2068294
# 1939  2059878
# ...       ...
# 1985  3245530
# 1986  3227500
# 1987  3265895
# 1988  3340519
# 1989  3475179
# 1990  3566331
# 1991  3502689
# 1992  3442170
# 1993  3363860
# 1994  3307185
# 1995  3249146
# 1996  3224919
# 1997  3193018
# 1998  3229407
# 1999  3233110
# 2000  3296850
# 2001  3250984
# 2002  3238053
# 2003  3288978
# 2004  3293984
# 2005  3305315
# 2006  3387737
# 2007  3412417
# 2008  3340318
# 2009  3232116
# 2010  3116548
# 2011  3079145
# 2012  3073858
# 2013  3066443
# 2014  3113611
#
# [105 rows x 1 columns]

# %%
series = df[cols].groupby('Year').sum()

# %%
series.plot(figsize=(18, 10), fontsize=16, lw=5)
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# Pequena gambiarra abaixo, vou colocar cada ano no formato 1-1-ANO. Assim o pandas sabe criar uma data.

# %%
new_series = series.copy()
['1-1-{}'.format(str(x)) for x in new_series.index]
# Out:
# ['1-1-1910',
#  '1-1-1911',
#  '1-1-1912',
#  '1-1-1913',
#  '1-1-1914',
#  '1-1-1915',
#  '1-1-1916',
#  '1-1-1917',
#  '1-1-1918',
#  '1-1-1919',
#  '1-1-1920',
#  '1-1-1921',
#  '1-1-1922',
#  '1-1-1923',
#  '1-1-1924',
#  '1-1-1925',
#  '1-1-1926',
#  '1-1-1927',
#  '1-1-1928',
#  '1-1-1929',
#  '1-1-1930',
#  '1-1-1931',
#  '1-1-1932',
#  '1-1-1933',
#  '1-1-1934',
#  '1-1-1935',
#  '1-1-1936',
#  '1-1-1937',
#  '1-1-1938',
#  '1-1-1939',
#  '1-1-1940',
#  '1-1-1941',
#  '1-1-1942',
#  '1-1-1943',
#  '1-1-1944',
#  '1-1-1945',
#  '1-1-1946',
#  '1-1-1947',
#  '1-1-1948',
#  '1-1-1949',
#  '1-1-1950',
#  '1-1-1951',
#  '1-1-1952',
#  '1-1-1953',
#  '1-1-1954',
#  '1-1-1955',
#  '1-1-1956',
#  '1-1-1957',
#  '1-1-1958',
#  '1-1-1959',
#  '1-1-1960',
#  '1-1-1961',
#  '1-1-1962',
#  '1-1-1963',
#  '1-1-1964',
#  '1-1-1965',
#  '1-1-1966',
#  '1-1-1967',
#  '1-1-1968',
#  '1-1-1969',
#  '1-1-1970',
#  '1-1-1971',
#  '1-1-1972',
#  '1-1-1973',
#  '1-1-1974',
#  '1-1-1975',
#  '1-1-1976',
#  '1-1-1977',
#  '1-1-1978',
#  '1-1-1979',
#  '1-1-1980',
#  '1-1-1981',
#  '1-1-1982',
#  '1-1-1983',
#  '1-1-1984',
#  '1-1-1985',
#  '1-1-1986',
#  '1-1-1987',
#  '1-1-1988',
#  '1-1-1989',
#  '1-1-1990',
#  '1-1-1991',
#  '1-1-1992',
#  '1-1-1993',
#  '1-1-1994',
#  '1-1-1995',
#  '1-1-1996',
#  '1-1-1997',
#  '1-1-1998',
#  '1-1-1999',
#  '1-1-2000',
#  '1-1-2001',
#  '1-1-2002',
#  '1-1-2003',
#  '1-1-2004',
#  '1-1-2005',
#  '1-1-2006',
#  '1-1-2007',
#  '1-1-2008',
#  '1-1-2009',
#  '1-1-2010',
#  '1-1-2011',
#  '1-1-2012',
#  '1-1-2013',
#  '1-1-2014']

# %% [markdown]
# Depois vou criar um novo índice

# %%
dates = pd.to_datetime(['15-6-{}'.format(str(x)) for x in new_series.index])
new_series.index = pd.DatetimeIndex(dates)
new_series
# Out:
#               Count
# 1910-06-15   516318
# 1911-06-15   565810
# 1912-06-15   887984
# 1913-06-15  1028553
# 1914-06-15  1293322
# 1915-06-15  1690022
# 1916-06-15  1786510
# 1917-06-15  1855696
# 1918-06-15  2013381
# 1919-06-15  1954834
# 1920-06-15  2101157
# 1921-06-15  2170892
# 1922-06-15  2127307
# 1923-06-15  2141692
# 1924-06-15  2218838
# 1925-06-15  2172403
# 1926-06-15  2137286
# 1927-06-15  2160249
# 1928-06-15  2105481
# 1929-06-15  2040623
# 1930-06-15  2070844
# 1931-06-15  1958859
# 1932-06-15  1964421
# 1933-06-15  1857674
# 1934-06-15  1933466
# 1935-06-15  1946981
# 1936-06-15  1936249
# 1937-06-15  1986759
# 1938-06-15  2068294
# 1939-06-15  2059878
# ...             ...
# 1985-06-15  3245530
# 1986-06-15  3227500
# 1987-06-15  3265895
# 1988-06-15  3340519
# 1989-06-15  3475179
# 1990-06-15  3566331
# 1991-06-15  3502689
# 1992-06-15  3442170
# 1993-06-15  3363860
# 1994-06-15  3307185
# 1995-06-15  3249146
# 1996-06-15  3224919
# 1997-06-15  3193018
# 1998-06-15  3229407
# 1999-06-15  3233110
# 2000-06-15  3296850
# 2001-06-15  3250984
# 2002-06-15  3238053
# 2003-06-15  3288978
# 2004-06-15  3293984
# 2005-06-15  3305315
# 2006-06-15  3387737
# 2007-06-15  3412417
# 2008-06-15  3340318
# 2009-06-15  3232116
# 2010-06-15  3116548
# 2011-06-15  3079145
# 2012-06-15  3073858
# 2013-06-15  3066443
# 2014-06-15  3113611
#
# [105 rows x 1 columns]

# %% [markdown]
# **Note o uso do mean** Podemos agregar de várias formas!

# %%
new_series.resample('10Y').mean().plot(figsize=(18, 10), fontsize=16, lw=5)
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# ### matplotlib
#
# Existe uma grande variedade de ferramentas para visualizar dados.
#
# Nós usaremos a biblioteca `matplotlib`, que é amplamente utilizada (embora mostre sua idade).
#
# Se você estiver interessado em produzir visualizações interativas elaboradas para a Web, provavelmente não é a escolha certa, mas para gráficos de barras simples, gráficos de linhas e diagramas de dispersão, funciona muito bem.

# %% [markdown]
# Em particular, estamos usando o módulo `matplotlib.pyplot`.
#
# Em seu uso mais simples, o `pyplot` mantém um estado interno no qual você constrói uma visualização passo a passo.
#
# Quando terminar, você poderá salvá-lo (com `savefig()`) ou exibi-lo (com `show()`).
#
# Vamos iniciar com duas listas simples de dados.

# %%
anos = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
pib = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
# cria um gráfico de linhas, com os anos no eixo x e o pib no eixo y
plt.plot(anos, pib)

# Adiciona um título
plt.title('Nominal GDP')

# Label nos eixos
plt.ylabel('Billions of USD')
plt.xlabel('Ano')

plt.show()

# %% [markdown]
# Podemos mudar a aparência usando estilos.

# %%
plt.style.use('seaborn')

# %%
# cria um gráfico de linhas, com os anos no eixo x e o pib no eixo y
plt.plot(anos, pib)

# Adiciona um título
plt.title('Nominal GDP')

# Label nos eixos
plt.ylabel('Billions of USD')
plt.xlabel('Ano')

plt.show()

# %% [markdown]
# Em particular, eu acho bom usar os estilos colorblind. Ajudam a fazer artigos científicos e garantir que todos entendam eu plot.

# %%
plt.style.available
# Out:
# ['bmh',
#  'fivethirtyeight',
#  'seaborn-pastel',
#  'seaborn-white',
#  'seaborn-bright',
#  'tableau-colorblind10',
#  'classic',
#  'seaborn-whitegrid',
#  'grayscale',
#  'seaborn-ticks',
#  'seaborn-darkgrid',
#  'dark_background',
#  'seaborn-talk',
#  'seaborn-paper',
#  'ggplot',
#  'fast',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn-dark-palette',
#  'Solarize_Light2',
#  'seaborn-deep',
#  'seaborn',
#  '_classic_test',
#  'seaborn-poster',
#  'seaborn-notebook',
#  'seaborn-dark']

# %%
# O comando abaixo precisa ser executada apenas uma vez, como já estamos no estilo seaborn
# o notebook deve continuar no mesmo.
# plt.style.use('seaborn-colorblind')

# %% [markdown]
# Podemos também usar vetores numpy sem problemas

# %%
x = np.linspace(-100, 100, 100) * 0.1
x
# Out:
# array([-10.        ,  -9.7979798 ,  -9.5959596 ,  -9.39393939,
#         -9.19191919,  -8.98989899,  -8.78787879,  -8.58585859,
#         -8.38383838,  -8.18181818,  -7.97979798,  -7.77777778,
#         -7.57575758,  -7.37373737,  -7.17171717,  -6.96969697,
#         -6.76767677,  -6.56565657,  -6.36363636,  -6.16161616,
#         -5.95959596,  -5.75757576,  -5.55555556,  -5.35353535,
#         -5.15151515,  -4.94949495,  -4.74747475,  -4.54545455,
#         -4.34343434,  -4.14141414,  -3.93939394,  -3.73737374,
#         -3.53535354,  -3.33333333,  -3.13131313,  -2.92929293,
#         -2.72727273,  -2.52525253,  -2.32323232,  -2.12121212,
#         -1.91919192,  -1.71717172,  -1.51515152,  -1.31313131,
#         -1.11111111,  -0.90909091,  -0.70707071,  -0.50505051,
#         -0.3030303 ,  -0.1010101 ,   0.1010101 ,   0.3030303 ,
#          0.50505051,   0.70707071,   0.90909091,   1.11111111,
#          1.31313131,   1.51515152,   1.71717172,   1.91919192,
#          2.12121212,   2.32323232,   2.52525253,   2.72727273,
#          2.92929293,   3.13131313,   3.33333333,   3.53535354,
#          3.73737374,   3.93939394,   4.14141414,   4.34343434,
#          4.54545455,   4.74747475,   4.94949495,   5.15151515,
#          5.35353535,   5.55555556,   5.75757576,   5.95959596,
#          6.16161616,   6.36363636,   6.56565657,   6.76767677,
#          6.96969697,   7.17171717,   7.37373737,   7.57575758,
#          7.77777778,   7.97979798,   8.18181818,   8.38383838,
#          8.58585859,   8.78787879,   8.98989899,   9.19191919,
#          9.39393939,   9.5959596 ,   9.7979798 ,  10.        ])

# %%
plt.plot(np.sin(x), label='Sine')
plt.plot(np.cos(x), label='Cosine')
plt.legend()

# %%
plt.plot(np.sin(x), np.cos(x))
plt.xlabel('Sine')
plt.ylabel('Cosine')
# Out:
# Text(0, 0.5, 'Cosine')

# %% [markdown]
# ## Movies Dataset
#
# Vamos olhar para mais ou menos 50 atores e algumas métricas dos filmes que os mesmos fazem parte. Em particular, vamos iniciar explorando uma forma de visualizar dados que é o histograma.

# %%
df = pd.read_csv('top_movies.csv')

# %%
df.head(6)
# Out:
#                           Title                Studio      Gross  \
# 0  Star Wars: The Force Awakens  Buena Vista (Disney)  906723418
# 1                        Avatar                   Fox  760507625
# 2                       Titanic             Paramount  658672302
# 3                Jurassic World             Universal  652270625
# 4         Marvel's The Avengers  Buena Vista (Disney)  623357910
# 5               The Dark Knight          Warner Bros.  534858444
#
#    Gross (Adjusted)  Year
# 0         906723400  2015
# 1         846120800  2009
# 2        1178627900  1997
# 3         687728000  2015
# 4         668866600  2012
# 5         647761600  2008

# %%
plt.figure(figsize=(18, 10))
mean_g = df.groupby('Studio').mean()['Gross (Adjusted)']
mean_g /= 1e8
ax = mean_g.sort_values()[::-1].plot.bar(fontsize=20)
plt.ylabel('Média de Lucro em Milhões')
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(20)

# %%
mean_g = df.groupby('Studio').mean()['Gross (Adjusted)']
mean_g /= 1e8
plt.figure(figsize=(18, 10))
plt.hist(mean_g)
plt.xlabel('Millions of Dollars')
plt.ylabel('# of Studios')

ax = plt.gca()
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(20)

# %% [markdown]
# ## Base de actors

# %%
df = pd.read_csv('actors.csv')
df
# Out:
#                      Actor  Total Gross  Number of Movies  Average per Movie  \
# 0            Harrison Ford       4871.7                41              118.8
# 1        Samuel L. Jackson       4772.8                69               69.2
# 2           Morgan Freeman       4468.3                61               73.3
# 3                Tom Hanks       4340.8                44               98.7
# 4       Robert Downey, Jr.       3947.3                53               74.5
# 5             Eddie Murphy       3810.4                38              100.3
# 6               Tom Cruise       3587.2                36               99.6
# 7              Johnny Depp       3368.6                45               74.9
# 8            Michael Caine       3351.5                58               57.8
# 9       Scarlett Johansson       3341.2                37               90.3
# 10             Gary Oldman       3294.0                38               86.7
# 11          Robin Williams       3279.3                49               66.9
# 12            Bruce Willis       3189.4                60               53.2
# 13       Stellan Skarsgard       3175.0                43               73.8
# 14         Anthony Daniels       3162.9                 7              451.8
# 15            Ian McKellen       3150.4                31              101.6
# 16              Will Smith       3149.1                24              131.2
# 17           Stanley Tucci       3123.9                50               62.5
# 18              Matt Damon       3107.3                39               79.7
# 19           Robert DeNiro       3081.3                79               39.0
# 20            Cameron Diaz       3031.7                34               89.2
# 21             Liam Neeson       2942.7                63               46.7
# 22             Andy Serkis       2890.6                23              125.7
# 23             Don Cheadle       2885.4                34               84.9
# 24             Ben Stiller       2827.0                37               76.4
# 25    Helena Bonham Carter       2822.0                36               78.4
# 26           Orlando Bloom       2815.8                17              165.6
# 27         Woody Harrelson       2815.8                50               56.3
# 28          Cate Blanchett       2802.6                39               71.9
# 29           Julia Roberts       2735.3                42               65.1
# 30         Elizabeth Banks       2726.3                35               77.9
# 31           Ralph Fiennes       2715.3                36               75.4
# 32             Emma Watson       2681.9                17              157.8
# 33         Tommy Lee Jones       2681.3                46               58.3
# 34               Brad Pitt       2680.9                40               67.0
# 35            Adam Sandler       2661.0                32               83.2
# 36        Daniel Radcliffe       2634.4                17              155.0
# 37              Jonah Hill       2605.1                29               89.8
# 38             Owen Wilson       2602.3                39               66.7
# 39              Idris Elba       2580.6                26               99.3
# 40          Bradley Cooper       2557.7                25              102.3
# 41           Mark Wahlberg       2549.8                36               70.8
# 42              Jim Carrey       2545.2                27               94.3
# 43          Dustin Hoffman       2522.1                43               58.7
# 44       Leonardo DiCaprio       2518.3                25              100.7
# 45           Jeremy Renner       2500.3                21              119.1
# 46  Philip Seymour Hoffman       2463.7                40               61.6
# 47          Sandra Bullock       2462.6                35               70.4
# 48             Chris Evans       2457.8                23              106.9
# 49           Anne Hathaway       2416.5                25               96.7
#
#                                #1 Movie  Gross
# 0          Star Wars: The Force Awakens  936.7
# 1                          The Avengers  623.4
# 2                       The Dark Knight  534.9
# 3                           Toy Story 3  415.0
# 4                          The Avengers  623.4
# 5                               Shrek 2  441.2
# 6                     War of the Worlds  234.3
# 7                      Dead Man's Chest  423.3
# 8                       The Dark Knight  534.9
# 9                          The Avengers  623.4
# 10                      The Dark Knight  534.9
# 11                  Night at the Museum  250.9
# 12                          Sixth Sense  293.5
# 13                         The Avengers  623.4
# 14         Star Wars: The Force Awakens  936.7
# 15                   Return of the King  377.8
# 16                     Independence Day  306.2
# 17                        Catching Fire  424.7
# 18                          The Martian  228.4
# 19                     Meet the Fockers  279.3
# 20                              Shrek 2  441.2
# 21                   The Phantom Menace  474.5
# 22         Star Wars: The Force Awakens  936.7
# 23              Avengers: Age of Ultron  459.0
# 24                     Meet the Fockers  279.3
# 25  Harry Potter / Deathly Hallows (P2)  381.0
# 26                     Dead Man's Chest  423.3
# 27                        Catching Fire  424.7
# 28                   Return of the King  377.8
# 29                       Ocean's Eleven  183.4
# 30                        Catching Fire  424.7
# 31  Harry Potter / Deathly Hallows (P2)  381.0
# 32  Harry Potter / Deathly Hallows (P2)  381.0
# 33                         Men in Black  250.7
# 34                          World War Z  202.4
# 35                 Hotel Transylvania 2  169.7
# 36  Harry Potter / Deathly Hallows (P2)  381.0
# 37                       The LEGO Movie  257.8
# 38                  Night at the Museum  250.9
# 39              Avengers: Age of Ultron  459.0
# 40                      American Sniper  350.1
# 41                       Transformers 4  245.4
# 42                           The Grinch  260.0
# 43                     Meet the Fockers  279.3
# 44                              Titanic  658.7
# 45                         The Avengers  623.4
# 46                        Catching Fire  424.7
# 47                              Minions  336.0
# 48                         The Avengers  623.4
# 49                The Dark Knight Rises  448.1

# %%
plt.figure(figsize=(18, 10))
plt.hist(df['Average per Movie'])
plt.xlabel('Média por Filme')
plt.ylabel('Número de linhas')
ax = plt.gca()
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(20)

# %%
plt.figure(figsize=(18, 10))
plt.hist(df['Average per Movie'], density=True)
plt.xlabel('Média por Filme')
plt.ylabel('P(x)')
ax = plt.gca()
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(20)

# %%
plt.figure(figsize=(18, 10))
data = df['Average per Movie'][df['Average per Movie'] < 100]
plt.xlabel('Média por Filme')
plt.ylabel('P(x)')
plt.hist(data, density=True)
ax = plt.gca()
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(20)

# %%
plt.figure(figsize=(18, 10))
data = df['Average per Movie']
plt.xlabel('Média por Filme')
plt.ylabel('P(x)')
plt.hist(data, density=True, bins=50)
ax = plt.gca()
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(20)

# %% [markdown]
# # Problemas de escala

# %%
plt.figure(figsize=(18, 10))
mentions = [500, 505]
years = [2013, 2014]

plt.bar(years, mentions)

plt.xticks(years)
plt.ylabel("# de vezes que escutei alguém dizer 'data science'")

# define o os limites do eixo y:
plt.ylim(499,506)

plt.title("Wow! Vejam que aumento!")

ax = plt.gca()
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(20)

# %%
plt.figure(figsize=(18, 10))

plt.bar(years, mentions)

plt.xticks(years)
plt.ylabel("# de vezes que escutei alguém dizer 'data science'")

plt.ylim(0, max(mentions)*1.1)
plt.title("Humm... Até que o aumento não foi tão grande.")

ax = plt.gca()
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(20)

# %% [markdown]
# # Dados 2d com e leitura de JSON

# %% [markdown]
# O pandas também sabe ler dados em json! Vamos tentar.

# %%
df = pd.read_json('capital.json')

# %%
df
# Out:
#      ano_dois  ano_um   cargo_pleiteado_1 cargo_pleiteado_2  \
# 0        2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 1        2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 2        2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 3        2018    2014     VICE-GOVERNADOR  DEPUTADO FEDERAL
# 4        2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 5        2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 6        2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 7        2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 8        2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 9        2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 10       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 11       2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 12       2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 13       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 14       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 15       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 16       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 17       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 18       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 19       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 20       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 21       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 22       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 23       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 24       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 25       2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 26       2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 27       2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 28       2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 29       2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# ..        ...     ...                 ...               ...
# 324      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 325      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 326      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 327      2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 328      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 329      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 330      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 331      2018    2014     VICE-GOVERNADOR  DEPUTADO FEDERAL
# 332      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 333      2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 334      2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 335      2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 336      2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 337      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 338      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 339      2018    2014     VICE-GOVERNADOR  DEPUTADO FEDERAL
# 340      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 341      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 342      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 343      2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 344      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 345      2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 346      2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 347      2018    2014  DEPUTADO DISTRITAL  DEPUTADO FEDERAL
# 348      2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 349      2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 350      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 351      2018    2014   DEPUTADO ESTADUAL  DEPUTADO FEDERAL
# 352      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
# 353      2018    2014    DEPUTADO FEDERAL  DEPUTADO FEDERAL
#
#     cod_unidade_eleitoral_1 cod_unidade_eleitoral_2          cpf estado  \
# 0                        MG                      MG      1608657     MG
# 1                        RJ                      RJ      7487738     RJ
# 2                        BA                      BA     31226540     BA
# 3                        CE                      CE    113735391     CE
# 4                        SP                      SP    168780860     SP
# 5                        RS                      RS    213461005     RS
# 6                        RJ                      RJ    262905701     RJ
# 7                        MS                      MS    263382893     MS
# 8                        SP                      SP    398099863     SP
# 9                        MA                      MA    441514383     MA
# 10                       SP                      SP    480584400     SP
# 11                       SC                      SC    503190942     SC
# 12                       PR                      PR    506342913     PR
# 13                       SP                      SP    551632895     SP
# 14                       RJ                      RJ    590048783     RJ
# 15                       PA                      PA    605387249     PA
# 16                       MG                      MG    649039661     MG
# 17                       AM                      AM    694584215     AM
# 18                       PB                      PB    770338410     PB
# 19                       MT                      MT    834939134     MT
# 20                       PI                      PI   1102125334     PI
# 21                       AL                      AL   1117690199     AL
# 22                       RS                      RS   1171688075     RS
# 23                       SP                      SP   1252958803     SP
# 24                       MG                      MG   1266637699     MG
# 25                       RJ                      RJ   1416576770     RJ
# 26                       TO                      TO   1657051161     TO
# 27                       RS                      RS   1738506002     RS
# 28                       RO                      RO   1739396782     RO
# 29                       PI                      PI   1742564348     PI
# ..                      ...                     ...          ...    ...
# 324                      MG                      MG  83035605653     MG
# 325                      PE                      PE  83146270463     PE
# 326                      RO                      RO  83577572272     RO
# 327                      MA                      MA  83762116334     MA
# 328                      MG                      MG  84470666653     MG
# 329                      MG                      MG  84719850634     MG
# 330                      MA                      MA  85290211349     MA
# 331                      DF                      DF  85773875187     DF
# 332                      PE                      PE  86488023420     PE
# 333                      MG                      MG  86753991620     MG
# 334                      BA                      BA  87594749120     BA
# 335                      PB                      PB  88623327420     PB
# 336                      RS                      RS  89718925015     RS
# 337                      MG                      MG  90330862634     MG
# 338                      SP                      SP  91311233849     SP
# 339                      MS                      MS  93132620106     MS
# 340                      RO                      RO  93279493234     RO
# 341                      SP                      SP  93876912849     SP
# 342                      MG                      MG  94892393649     MG
# 343                      SC                      SC  95128140997     SC
# 344                      RJ                      RJ  95188100606     RJ
# 345                      RJ                      RJ  95622780772     RJ
# 346                      RS                      RS  95887105020     RS
# 347                      DF                      DF  96311380110     DF
# 348                      RS                      RS  96520418072     RS
# 349                      ES                      ES  98042734700     ES
# 350                      MS                      MS  98303651749     MS
# 351                      PR                      PR  98451278949     PR
# 352                      MG                      MG  99316552672     MG
# 353                      TO                      TO  99898659149     TO
#
#                   nome_urna  patrimonio_eleicao_1  patrimonio_eleicao_2  \
# 0            Stefano Aguiar            2326963.85            2890296.74
# 1            Altineu Cortes            4239563.82            3943907.61
# 2       Mário Negromonte Jr            1077668.74            2281417.64
# 3            Roberto Pessoa           14399524.97           13160762.14
# 4               Vitor Lippi             713217.64             972916.79
# 5       Fernanda Melchionna             106070.38              96319.25
# 6               Pedro Paulo             553144.11             341805.65
# 7                 Dagoberto            2712509.62            3093645.23
# 8          Carlos Zarattini             600772.54            1051302.81
# 9             Rubens Junior             653912.76             801591.36
# 10           Luiza Erundina             897323.15            1293077.73
# 11          Carlos Chiodini             141030.05              94134.28
# 12           Aline Sleutjes             123173.75             132498.54
# 13         Herculano Passos            5197664.86            4991933.06
# 14             Rodrigo Maia             736000.00             730615.48
# 15                  Elcione            5173997.99            3613643.30
# 16   Marcelo Alvaro Antonio             455000.00             773125.00
# 17               Atila Lins            1880767.00            2434990.10
# 18             Efraim Filho             893609.42             873721.28
# 19           Carlos Bezerra            2137746.28            1519519.15
# 20              Júlio Cesar            2008505.41            2183156.52
# 21                      Jhc            3129526.00            2399418.33
# 22            Covatti Filho             472496.08             956901.59
# 23         Celso Russomanno            1748539.86            1797223.56
# 24        Newton Cardoso Jr            1797026.57            2030880.92
# 25         Alessandro Molon              26012.85            1680523.07
# 26              Tiago Dimas             193600.00             328357.81
# 27            Liziane Bayer             219796.27             212200.35
# 28          Silvia Cristina             165820.85             293762.30
# 29   Marcos Aurelio Sampaio              84490.00             319437.69
# ..                      ...                   ...                   ...
# 324       Rodrigo De Castro            1860637.47            1664606.19
# 325       Fernando Monteiro            1276791.72             529371.45
# 326        Mariana Carvalho             497883.84            2718054.52
# 327                Edilazio            2013926.36            5362203.08
# 328           Eros Biondini            1052050.00            1380234.85
# 329           Weliton Prado             927149.04            1726477.26
# 330         Juscelino Filho            3249116.66            3930767.09
# 331           Flavia Arruda             940613.01             774926.00
# 332         Felipe Carreras           11707580.13            5975619.27
# 333            Paulo Guedes             918767.05            1301221.35
# 334         Leur Lomanto Jr             497825.73             341660.21
# 335           Gervásio Maia            2722915.88            2893556.70
# 336           Marlon Santos             152950.00            1233329.40
# 337         Reginaldo Lopes             788253.65             622916.10
# 338      General Peternelli            7453000.00            2245633.50
# 339            Rose Modesto             139356.74             283563.76
# 340          Expedito Netto            1775000.00              88550.63
# 341      Paulo Freire Costa             987534.04            1154699.85
# 342             Odair Cunha             642000.00            1352083.52
# 343           Ricardo Guidi            1046651.72            1209274.36
# 344                Sóstenes              67500.00             134689.48
# 345          Marcelo Freixo              29749.02              13918.01
# 346     Maurício Dziedricki             455300.42             308989.06
# 347        Professor Israel              72994.19             171623.00
# 348          Marcelo Moraes             434486.29             658577.08
# 349              Da Vitoria            1067048.16            1230601.08
# 350              Fabio Trad            1011914.88            1696699.51
# 351           Ney Leprevost             376567.41            1131122.02
# 352           Diego Andrade            1647125.17            1289581.91
# 353       Vicentinho Junior            2476968.31            3110990.70
#
#      sequencial_candidato_1  sequencial_candidato_2 sigla_partido  \
# 0              130000001189            130000613225           PSD
# 1              190000001858            190000604181            PR
# 2               50000000167             50000605225            PP
# 3               60000000604             60000611570          PSDB
# 4              250000001354            250000605413          PSDB
# 5              210000000014            210000600043          PSOL
# 6              190000001428            190000607425           DEM
# 7              120000000508            120000602218           PDT
# 8              250000000618            250000623897            PT
# 9              100000000627            100000601890       PC do B
# 10             250000001476            250000601478          PSOL
# 11             240000000273            240000609546           MDB
# 12             160000001104            160000626150           PSL
# 13             250000002189            250000604091           MDB
# 14             190000001114            190000607414           DEM
# 15             140000000455            140000606359           MDB
# 16             130000001127            130000616635           PSL
# 17              40000000356             40000610407            PP
# 18             150000000207            150000608820           DEM
# 19             110000000304            110000622434           MDB
# 20             180000000054            180000613937           PSD
# 21              20000000183             20000616803           PSB
# 22             210000000638            210000604833            PP
# 23             250000001257            250000606220           PRB
# 24             130000000886            130000620820           MDB
# 25             190000000614            190000615553           PSB
# 26             270000000266            270000618825    SOLIDARIED
# 27             210000000550            210000600965           PSB
# 28             220000000260            220000611027           PDT
# 29             180000000098            180000613906           MDB
# ..                      ...                     ...           ...
# 324            130000000661            130000613203          PSDB
# 325            170000000069            170000614072            PP
# 326            220000000030            220000609734          PSDB
# 327            100000000742            100000609118           PSD
# 328            130000000120            130000620684          PROS
# 329            130000000907            130000620691          PROS
# 330            100000000505            100000601901           DEM
# 331             70000001546             70000625528            PR
# 332            170000000047            170000610285           PSB
# 333            130000000978            130000626968            PT
# 334             50000000748             50000608636           DEM
# 335            150000000162            150000608801           PSB
# 336            210000000201            210000604635           PDT
# 337            130000000894            130000626978            PT
# 338            250000000418            250000613307           PSL
# 339            120000000023            120000613457          PSDB
# 340            220000000037            220000609735           PSD
# 341            250000000700            250000619412            PR
# 342            130000000889            130000626966            PT
# 343            240000000567            240000627211           PSD
# 344            190000001488            190000607427           DEM
# 345            190000000419            190000602109          PSOL
# 346            210000000830            210000604804           PTB
# 347             70000000265             70000614421            PV
# 348            210000000825            210000604803           PTB
# 349             80000000377             80000611885           PPS
# 350            120000000109            120000613463           PSD
# 351            160000000566            160000619715           PSD
# 352            130000000716            130000613218           PSD
# 353            270000000292            270000610948            PR
#
#     situacao_eleicao_1 situacao_eleicao_2   unidade_eleitoral
# 0               ELEITO             ELEITO        Minas Gerais
# 1               ELEITO             ELEITO      Rio De Janeiro
# 2               ELEITO             ELEITO               Bahia
# 3           NÃO ELEITO             ELEITO               Ceará
# 4               ELEITO             ELEITO           São Paulo
# 5           NÃO ELEITO             ELEITO   Rio Grande Do Sul
# 6               ELEITO             ELEITO      Rio De Janeiro
# 7               ELEITO             ELEITO  Mato Grosso Do Sul
# 8               ELEITO             ELEITO           São Paulo
# 9               ELEITO             ELEITO            Maranhão
# 10              ELEITO             ELEITO           São Paulo
# 11              ELEITO             ELEITO      Santa Catarina
# 12          NÃO ELEITO             ELEITO              Paraná
# 13              ELEITO             ELEITO           São Paulo
# 14              ELEITO             ELEITO      Rio De Janeiro
# 15              ELEITO             ELEITO                Pará
# 16              ELEITO             ELEITO        Minas Gerais
# 17              ELEITO             ELEITO            Amazonas
# 18              ELEITO             ELEITO             Paraíba
# 19              ELEITO             ELEITO         Mato Grosso
# 20              ELEITO             ELEITO               Piauí
# 21              ELEITO             ELEITO             Alagoas
# 22              ELEITO             ELEITO   Rio Grande Do Sul
# 23              ELEITO             ELEITO           São Paulo
# 24              ELEITO             ELEITO        Minas Gerais
# 25              ELEITO             ELEITO      Rio De Janeiro
# 26          NÃO ELEITO             ELEITO           Tocantins
# 27              ELEITO             ELEITO   Rio Grande Do Sul
# 28          NÃO ELEITO             ELEITO            Rondônia
# 29          NÃO ELEITO             ELEITO               Piauí
# ..                 ...                ...                 ...
# 324             ELEITO             ELEITO        Minas Gerais
# 325         NÃO ELEITO             ELEITO          Pernambuco
# 326             ELEITO             ELEITO            Rondônia
# 327             ELEITO             ELEITO            Maranhão
# 328             ELEITO             ELEITO        Minas Gerais
# 329             ELEITO             ELEITO        Minas Gerais
# 330             ELEITO             ELEITO            Maranhão
# 331         NÃO ELEITO             ELEITO    Distrito Federal
# 332             ELEITO             ELEITO          Pernambuco
# 333             ELEITO             ELEITO        Minas Gerais
# 334             ELEITO             ELEITO               Bahia
# 335             ELEITO             ELEITO             Paraíba
# 336             ELEITO             ELEITO   Rio Grande Do Sul
# 337             ELEITO             ELEITO        Minas Gerais
# 338         NÃO ELEITO             ELEITO           São Paulo
# 339             ELEITO             ELEITO  Mato Grosso Do Sul
# 340             ELEITO             ELEITO            Rondônia
# 341             ELEITO             ELEITO           São Paulo
# 342             ELEITO             ELEITO        Minas Gerais
# 343             ELEITO             ELEITO      Santa Catarina
# 344             ELEITO             ELEITO      Rio De Janeiro
# 345             ELEITO             ELEITO      Rio De Janeiro
# 346             ELEITO             ELEITO   Rio Grande Do Sul
# 347             ELEITO             ELEITO    Distrito Federal
# 348             ELEITO             ELEITO   Rio Grande Do Sul
# 349             ELEITO             ELEITO      Espírito Santo
# 350         NÃO ELEITO             ELEITO  Mato Grosso Do Sul
# 351             ELEITO             ELEITO              Paraná
# 352             ELEITO             ELEITO        Minas Gerais
# 353             ELEITO             ELEITO           Tocantins
#
# [354 rows x 17 columns]

# %%
plt.figure(figsize=(18, 10))
plt.scatter(df['patrimonio_eleicao_1'], df['patrimonio_eleicao_2'])
linha45 = np.unique(df['patrimonio_eleicao_1'])
plt.plot(linha45, )

ax = plt.gca()
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(20)
